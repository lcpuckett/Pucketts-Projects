# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#imdb reviews of shows! maybe try using matplot lib on this one, lots of categorical data
df1= pd.read_csv(r"C:\Users\latri\Desktop\Latrice tech growth\Datas\IMBD.csv")
df1
# Out:
#       Unnamed: 0      id                      name origin_country  \
# 0              0  130392         The D'Amelio Show         ['US']
# 1              1     100        I Am Not an Animal         ['GB']
# 2              2   94605                    Arcane         ['US']
# 3              3  124834              Heartstopper         ['GB']
# 4              4   19239  Conan, the Boy in Future         ['JP']
# ...          ...     ...                       ...            ...
# 2455        2455    1769               Johnny Test   ['CA', 'US']
# 2456        2456   67132            Kevin Can Wait         ['US']
# 2457        2457    4551      America's Got Talent         ['US']
# 2458        2458     987          General Hospital         ['US']
# 2459        2459    5917                     90210         ['US']
#
#      original_language         original_name  popularity  vote_average  \
# 0                   en     The D'Amelio Show      15.457           9.4
# ...

# %%
df1.describe
# Out:
# <bound method NDFrame.describe of       Unnamed: 0      id                      name origin_country  \
# 0              0  130392         The D'Amelio Show         ['US']
# 1              1     100        I Am Not an Animal         ['GB']
# 2              2   94605                    Arcane         ['US']
# 3              3  124834              Heartstopper         ['GB']
# 4              4   19239  Conan, the Boy in Future         ['JP']
# ...          ...     ...                       ...            ...
# 2455        2455    1769               Johnny Test   ['CA', 'US']
# 2456        2456   67132            Kevin Can Wait         ['US']
# 2457        2457    4551      America's Got Talent         ['US']
# 2458        2458     987          General Hospital         ['US']
# 2459        2459    5917                     90210         ['US']
#
#      original_language         original_name  popularity  vote_average  \
# ...

# %%
#looking at the information of famous dead people, could so some good recoding on this and look at correlations to age of death
#does occupation/ gender predict age of death, etc
df2= pd.read_csv(r"C:\Users\latri\Desktop\Latrice tech growth\Datas\AgeData.csv")
df2
# Out:
#                 Id                     Name  \
# 0              Q23        George Washington
# 1              Q42            Douglas Adams
# 2              Q91          Abraham Lincoln
# 3             Q254  Wolfgang Amadeus Mozart
# 4             Q255     Ludwig van Beethoven
# ...            ...                      ...
# 1223004  Q77247326    Marie-Fortunée Besson
# 1223005  Q77249504              Ron Thorsen
# 1223006  Q77249818       Diether Todenhagen
# 1223007  Q77253909  Reginald Oswald Pearson
# 1223008  Q77254864             Horst Lerche
#
#                                          Short description Gender  \
# 0           1st president of the United States (1732–1799)   Male
# 1                              English writer and humorist   Male
# 2          16th president of the United States (1809-1865)   Male
# 3                Austrian composer of the Classical period   Male
# 4                   German classical and romantic composer   Male
# ...
